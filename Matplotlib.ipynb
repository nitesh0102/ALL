# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.random.rand(50)

# %%
y  =np.random.rand(50)

# %%
x
# Out:
# array([0.74314279, 0.6607948 , 0.1857059 , 0.12288624, 0.22643809,
#        0.72718527, 0.91894996, 0.9934115 , 0.40750541, 0.24645198,
#        0.94809424, 0.21024894, 0.71975595, 0.64645211, 0.29009224,
#        0.05896224, 0.29911023, 0.95758839, 0.67877077, 0.96892105,
#        0.69682853, 0.29095541, 0.44072656, 0.46249619, 0.73058425,
#        0.98931641, 0.97034774, 0.15731817, 0.78500048, 0.68310579,
#        0.11951896, 0.3779615 , 0.58886796, 0.93925944, 0.45670105,
#        0.05157198, 0.97796915, 0.3969266 , 0.68558507, 0.57418996,
#        0.33606764, 0.39525384, 0.95280775, 0.25690725, 0.20111178,
#        0.09304577, 0.69062409, 0.18721138, 0.9351135 , 0.2587181 ])

# %%
y
# Out:
# array([0.26423091, 0.30314015, 0.27070821, 0.06444232, 0.98637971,
#        0.49691468, 0.36884918, 0.11048092, 0.96388414, 0.85854763,
#        0.73747032, 0.99217729, 0.55364901, 0.04343025, 0.52006361,
#        0.18449969, 0.9147241 , 0.44649582, 0.59065057, 0.92613038,
#        0.65913567, 0.22291199, 0.9447194 , 0.94512528, 0.14972448,
#        0.24985643, 0.2897477 , 0.15569392, 0.61065327, 0.82892957,
#        0.21283944, 0.81679158, 0.56867791, 0.00713912, 0.19601498,
#        0.62301301, 0.35663734, 0.66567332, 0.94590966, 0.25444932,
#        0.78718416, 0.85100121, 0.32640072, 0.19860134, 0.72296604,
#        0.07112095, 0.80102316, 0.30849843, 0.19620677, 0.79695307])

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y, color = 'r',alpha = .5,marker = '*')
plt.xlabel("this is my x-axes")
plt.ylabel("this is my y-axes")
plt.title("x-y scatter plot")
# Out:
# Text(0.5, 1.0, 'x-y scatter plot')

# %%
x = np.linspace(1,10,10)
y = np.sin(x)

# %%
plt.plot(x,y,'--')

# %%
plt.bar(x,y)
plt.figure(figsize = (5,3))

# %%
x = [1,2,3,4,5]
y = [2,3,4,5,6]

# %%
plt.plot(x,y)
