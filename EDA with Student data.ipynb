# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Downloads\exams (1).csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group E            some high school  free/reduced
# 1    male        group B           bachelor's degree      standard
# 2  female        group B          associate's degree      standard
# 3    male        group E             master's degree      standard
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          59             66             68
# 1                    none          73             76             70
# 2                    none          77             87             84
# 3                    none         100             91             85
# 4                    none          80             66             62

# %% [markdown]
# #Data Checks to perform
# 1. Check Missing Values
# 2. Check Duplicates
# 3. Check Data Type
# 4. Check the number of unique values of each column
# 5. check statistics of the data set
# 6. check various categories present in the different categorical column

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     77
# reading score                  75
# writing score                  78
# dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  996.000000     996.000000     996.000000
# mean    67.492972      70.056225      68.516064
# std     15.397218      14.722589      15.452139
# min     10.000000      14.000000       9.000000
# 25%     57.000000      61.000000      59.000000
# 50%     67.000000      71.000000      69.000000
# 75%     79.000000      80.000000      79.000000
# max    100.000000     100.000000     100.000000

# %%
df.shape
# Out:
# (996, 8)

# %%
[x for x in df.columns if df[x].dtype != 'O']
# Out:
# ['math score', 'reading score', 'writing score']

# %%
[Y for Y in df.columns]
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %%
numerical_features = [ x for x in df.columns if df[x].dtype != 'O']

# %%
cat_features = [ x for x in df.columns if df[x].dtype == 'O']

# %%
numerical_features
# Out:
# ['math score', 'reading score', 'writing score']

# %%
cat_features
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
df['avg'] = df['total_score']/3

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group E            some high school  free/reduced
# 1      male        group B           bachelor's degree      standard
# 2    female        group B          associate's degree      standard
# 3      male        group E             master's degree      standard
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995    male        group C            some high school      standard
# 996  female        group C           bachelor's degree      standard
# 997    male        group B                 high school      standard
# 998    male        group C          associate's degree      standard
# 999    male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
## visualisation

# %%
fig,axis = plt.subplots(1,2,figsize= (15,7))
plt.subplot(121)
sns.histplot(data = df, x = 'avg',bins = 30 , kde = True, color = 'g')
plt.subplot(122)
sns.histplot(data = df, x = 'avg',bins = 30 , kde = True, color = 'g', hue  = 'gender')
# Out:
# <Axes: xlabel='avg', ylabel='Count'>

# %%
fig,axis = plt.subplots(1,2, figsize = (15,7))
plt.subplot(141)
sns.histplot(data = df, x = 'avg', bins = 30, kde = True, color = 'g')
plt.subplot(142)
sns.histplot(data = df, x = 'avg', bins = 30, kde = True, color = 'b', hue = 'gender')
plt.subplot(143)
sns.histplot(data = df[df.gender == 'male'], x = 'avg',kde= True,color = 'v', hue = 'lunch')
#plt.show()
# Out:
# <Axes: xlabel='avg', ylabel='Count'>

# %%
# Out:
# UsageError: Line magic function `%m` not found.

# %%
sns.pairplot(df)

# %%
df[df[x for x in df[x].dtype != 'O']]
# Out:
#   Cell In[76], line 1
#     df[df[x for x in df[x].dtype != 'O']]
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 sns.heatmap(df.corr(),annot = True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...
